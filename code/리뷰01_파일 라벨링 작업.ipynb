# %%
# 리뷰 파일 레이블링 작업

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/물놀이/review_crawling_normal.csv')
df
# Out:
#             물놀이장                                                 리뷰
# 0     희망어린이공원 계류  원래는 소귀어린이공원(잠자리놀이터)을 자주 이용했었는데... 벤치도 그렇고 미끄럼틀...
# 1     희망어린이공원 계류                                 풍경을바라보며쉴수있는좋은공간이에요
# 2     희망어린이공원 계류                                  공동 화장실이 있었음 좋겠어요~
# 3     희망어린이공원 계류                          어린이들이 맘껏  뛰어놀수있는. 그런공간이네요
# 4     희망어린이공원 계류                           어린이 놀이터가 있는 공원 - 화장실은 없다
# ...          ...                                                ...
# 2350       공 릉 동                                                좋아요
# 2351       공 릉 동  공원은 그렇게 좋지 않습니다. 3면이 도로로 둘러싸여 있습니다. 그들은 최근에 '미...
# 2352       공 릉 동                           산책과 휴식을 취하기에 너무 좋은 곳입니다.
# 2353       공 릉 동                                    많이 붐비지 않고 깨끗합니다
# 2354       공 릉 동                                         거기에 있어야합니다
#
# [2355 rows x 2 columns]

# %%
# 부정어 리스트
keywords = ['아쉽', '아쉬운' ,'지저분', '쓰레기', '소음','담배', '답답해요', '혼잡', '바글바글', '불편', '위험', '복잡',
            '무서운', '무섭', '너무 많', '비싸', '바가지', '더럽', '아깝', '아까워', '가지마', '안좋을', '안좋', 
           '냄새가 나', '냄새나', '노숙자', '너무 더럽', '피부병', '더러워', '협소', '너무 없', '불가능', '마스크 안', '주차할 곳이 없',
            '주차할 곳 없', '할아버지들', '좀 그랬', '대변', '소변', '시끄', '불법주차', '불쾌', '관리 필요', '관리는 필요',
            '노잼', '폐쇄', '냄새가 심', '주차 힘', '음 좋겠', '물비린내', '어두워', '규모가 작', '흡연', '비위생', '개똥'
            '유명무실', '부족', '볼거 없', '볼건 없', '무서운', '불친절', '갈 생각 없', '짜증', '개판', '악취',
            '힘듦', '나쁘다', '나쁨', '인상이 찌푸', '인상 찌푸', '좋지 않음', '술먹고', '지저분', '별로', '물이 더러워', '물이 드러워',
            '깡패', '접근성이 떨어', '접근성 떨어', '좋지 않', '화장실이 없', '화장실은 없', '안나와요','개 풀','음주', '아쉬움']
keywords.sort()

# %%
keywords
# Out:
# ['가지마',
#  '갈 생각 없',
#  '개 풀',
#  '개판',
#  '관리 필요',
#  '관리는 필요',
#  '규모가 작',
#  '깡패',
#  '나쁘다',
#  '나쁨',
#  '냄새가 나',
#  '냄새가 심',
#  '냄새나',
#  '너무 더럽',
#  '너무 많',
#  '너무 없',
#  '노숙자',
#  '노잼',
#  '담배',
#  '답답해요',
#  '대변',
#  '더러워',
#  '더럽',
#  '마스크 안',
#  '무서운',
#  '무서운',
#  '무섭',
#  '물비린내',
#  '물이 더러워',
#  '물이 드러워',
#  '바가지',
#  '바글바글',
#  '별로',
#  '복잡',
#  '볼거 없',
#  '볼건 없',
#  '부족',
#  '불가능',
#  '불법주차',
#  '불친절',
#  '불쾌',
#  '불편',
#  '비싸',
#  '비위생',
#  '소변',
#  '소음',
#  '술먹고',
#  '시끄',
#  '쓰레기',
#  '아까워',
#  '아깝',
#  '아쉬운',
#  '아쉽',
#  '안나와요',
#  '안좋',
#  '안좋을',
#  '어두워',
#  '위험',
#  '유명무실',
#  '음 좋겠',
#  '인상 찌푸',
#  '인상이 찌푸',
#  '접근성 떨어',
#  '접근성이 떨어',
#  '좀 그랬',
#  '좋지 않',
#  '좋지 않음',
#  '주차 힘',
#  '주차할 곳 없',
#  '주차할 곳이 없',
#  '지저분',
#  '지저분',
#  '짜증',
#  '폐쇄',
#  '피부병',
#  '할아버지들',
#  '협소',
#  '혼잡',
#  '화장실은 없',
#  '화장실이 없',
#  '흡연',
#  '힘듦']

# %%
df['label'] = 1
df
# Out:
#             물놀이장                                                 리뷰  label
# 0     희망어린이공원 계류  원래는 소귀어린이공원(잠자리놀이터)을 자주 이용했었는데... 벤치도 그렇고 미끄럼틀...      1
# 1     희망어린이공원 계류                                 풍경을바라보며쉴수있는좋은공간이에요      1
# 2     희망어린이공원 계류                                  공동 화장실이 있었음 좋겠어요~      1
# 3     희망어린이공원 계류                          어린이들이 맘껏  뛰어놀수있는. 그런공간이네요      1
# 4     희망어린이공원 계류                           어린이 놀이터가 있는 공원 - 화장실은 없다      1
# ...          ...                                                ...    ...
# 2350       공 릉 동                                                좋아요      1
# 2351       공 릉 동  공원은 그렇게 좋지 않습니다. 3면이 도로로 둘러싸여 있습니다. 그들은 최근에 '미...      1
# 2352       공 릉 동                           산책과 휴식을 취하기에 너무 좋은 곳입니다.      1
# 2353       공 릉 동                                    많이 붐비지 않고 깨끗합니다      1
# 2354       공 릉 동                                         거기에 있어야합니다      1
#
# [2355 rows x 3 columns]

# %%
for idx, item in enumerate(df['리뷰']):
    if any(keyword in item for keyword in keywords):
        df.iat[idx, 2] = 0

# %%
df['label'].value_counts()
# Out:
# 1    2144
# 0     211
# Name: label, dtype: int64

# %%
df.head(30)
df.tail(30)
# Out:
#              물놀이장                                                 리뷰  label
# 0      희망어린이공원 계류  원래는 소귀어린이공원(잠자리놀이터)을 자주 이용했었는데... 벤치도 그렇고 미끄럼틀...      0
# 1      희망어린이공원 계류                                 풍경을바라보며쉴수있는좋은공간이에요      1
# 2      희망어린이공원 계류                                  공동 화장실이 있었음 좋겠어요~      0
# 3      희망어린이공원 계류                          어린이들이 맘껏  뛰어놀수있는. 그런공간이네요      1
# 4      희망어린이공원 계류                           어린이 놀이터가 있는 공원 - 화장실은 없다      0
# 5      희망어린이공원 계류                                     아이들이 놀러나오기 좋아요      1
# 6      희망어린이공원 계류                                           개 풀뜻어먹어요      0
# 7      희망어린이공원 계류                                                 소소      1
# 8      희망어린이공원 계류                                            공원이 이쁘다      1
# 9      희망어린이공원 계류                                             쉬기 좋은곳      1
# 10     희망어린이공원 계류                                                좋아요      1
# ...

# %%
df[0:30]
# Out:
#              물놀이장                                                 리뷰  label
# 0      희망어린이공원 계류  원래는 소귀어린이공원(잠자리놀이터)을 자주 이용했었는데... 벤치도 그렇고 미끄럼틀...      0
# 1      희망어린이공원 계류                                 풍경을바라보며쉴수있는좋은공간이에요      1
# 2      희망어린이공원 계류                                  공동 화장실이 있었음 좋겠어요~      0
# 3      희망어린이공원 계류                          어린이들이 맘껏  뛰어놀수있는. 그런공간이네요      1
# 4      희망어린이공원 계류                           어린이 놀이터가 있는 공원 - 화장실은 없다      0
# 5      희망어린이공원 계류                                     아이들이 놀러나오기 좋아요      1
# 6      희망어린이공원 계류                                           개 풀뜻어먹어요      0
# 7      희망어린이공원 계류                                                 소소      1
# 8      희망어린이공원 계류                                            공원이 이쁘다      1
# 9      희망어린이공원 계류                                             쉬기 좋은곳      1
# 10     희망어린이공원 계류                                                좋아요      1
# ...

# %%
df.to_csv('../../data/물놀이/review_crawling_normal_label.csv')

# %%
# 일단 여기까지 레이블링하고 파일 열어서 애매한 부분 수작업

# %%
####################################################################################

# %%
### 긍정어로

# %%
df = pd.read_csv('../../data/물놀이/review_crawling_normal.csv')
df
# Out:
#             물놀이장                                                 리뷰
# 0     희망어린이공원 계류  원래는 소귀어린이공원(잠자리놀이터)을 자주 이용했었는데... 벤치도 그렇고 미끄럼틀...
# 1     희망어린이공원 계류                                 풍경을바라보며쉴수있는좋은공간이에요
# 2     희망어린이공원 계류                                  공동 화장실이 있었음 좋겠어요~
# 3     희망어린이공원 계류                          어린이들이 맘껏  뛰어놀수있는. 그런공간이네요
# 4     희망어린이공원 계류                           어린이 놀이터가 있는 공원 - 화장실은 없다
# ...          ...                                                ...
# 2350       공 릉 동                                                좋아요
# 2351       공 릉 동  공원은 그렇게 좋지 않습니다. 3면이 도로로 둘러싸여 있습니다. 그들은 최근에 '미...
# 2352       공 릉 동                           산책과 휴식을 취하기에 너무 좋은 곳입니다.
# 2353       공 릉 동                                    많이 붐비지 않고 깨끗합니다
# 2354       공 릉 동                                         거기에 있어야합니다
#
# [2355 rows x 2 columns]

# %%
# 긍정어 리스트
keywords_good = ['좋아', '좋은', '편리', '가까', '깨끗', '조용', '시원', '예쁘', '예뻐', '이쁘', '재미있',
           '재밌', '탁트인', '쾌적', '아름다', '평화', '인상적', '좋네', '최고', '으뜸', '여유',
           '끝내', '끝네', '멋지' ,'좋습', '딱 이에요', '좋다',  '좋구', '좋고', '활기찬',
           '좋음', '예뻤', '멋졌', '잘 되어 있', '좋았',  '만족해', '만족한', '훌륭', '괜찮',
           '굿', '숨쉴 공간', '즐거운',  '공기 맑', '공기가 맑']
keywords_good.sort()

# %%
keywords_good
# Out:
# ['가까',
#  '공기 맑',
#  '공기가 맑',
#  '괜찮',
#  '굿',
#  '깨끗',
#  '끝내',
#  '끝네',
#  '딱 이에요',
#  '만족한',
#  '만족해',
#  '멋졌',
#  '멋지',
#  '숨쉴 공간',
#  '시원',
#  '아름다',
#  '여유',
#  '예뻐',
#  '예뻤',
#  '예쁘',
#  '으뜸',
#  '이쁘',
#  '인상적',
#  '잘 되어 있',
#  '재미있',
#  '재밌',
#  '조용',
#  '좋고',
#  '좋구',
#  '좋네',
#  '좋다',
#  '좋습',
#  '좋아',
#  '좋았',
#  '좋은',
#  '좋음',
#  '즐거운',
#  '최고',
#  '쾌적',
#  '탁트인',
#  '편리',
#  '평화',
#  '활기찬',
#  '훌륭']

# %%
df['label'] = 0
df
# Out:
#             물놀이장                                                 리뷰  label
# 0     희망어린이공원 계류  원래는 소귀어린이공원(잠자리놀이터)을 자주 이용했었는데... 벤치도 그렇고 미끄럼틀...      0
# 1     희망어린이공원 계류                                 풍경을바라보며쉴수있는좋은공간이에요      0
# 2     희망어린이공원 계류                                  공동 화장실이 있었음 좋겠어요~      0
# 3     희망어린이공원 계류                          어린이들이 맘껏  뛰어놀수있는. 그런공간이네요      0
# 4     희망어린이공원 계류                           어린이 놀이터가 있는 공원 - 화장실은 없다      0
# ...          ...                                                ...    ...
# 2350       공 릉 동                                                좋아요      0
# 2351       공 릉 동  공원은 그렇게 좋지 않습니다. 3면이 도로로 둘러싸여 있습니다. 그들은 최근에 '미...      0
# 2352       공 릉 동                           산책과 휴식을 취하기에 너무 좋은 곳입니다.      0
# 2353       공 릉 동                                    많이 붐비지 않고 깨끗합니다      0
# 2354       공 릉 동                                         거기에 있어야합니다      0
#
# [2355 rows x 3 columns]

# %%
for idx, item in enumerate(df['리뷰']):
    if any(keyword in item for keyword in keywords_good):
        df.iat[idx, 2] = 1

# %%
df['label'].value_counts()
# Out:
# 1    1402
# 0     953
# Name: label, dtype: int64

# %%
df.to_csv('../../data/물놀이/review_crawling_normal_label2.csv')
